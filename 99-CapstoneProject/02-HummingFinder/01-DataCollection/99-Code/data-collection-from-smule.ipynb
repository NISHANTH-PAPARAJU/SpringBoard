# %%
import urllib
import bs4

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
songs_list=["uppenantha","Karige"]

# %%
smule_base_url = "https://www.smule.com/"

# %%
song_urls = dict()
for song in songs_list:
    song_urls[song] = smule_base_url + "search?q=" + song
song_urls['uppenantha']
# Out:
# 'https://www.smule.com/search?q=uppenantha'

# %%
song_urls.values()
# Out:
# dict_values(['https://www.smule.com/search?q=uppenantha', 'https://www.smule.com/search?q=Karige'])

# %%
html_pages = {}
song_soups = {}
for song, url in song_urls.items():
    u_client = uReq(url)
    html_pages[song] = u_client.read()
    song_soups[song] = soup(u_client.read(), 'html.parser')
    u_client.close()
xyz = song_soups['uppenantha']
xyz.findAll("div",{class:"recording-results-container"})
# Out:
#   File "<ipython-input-86-60433dd657bd>", line 9
#     xyz.findAll("div",{class:"recording-results-container"})
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Automated Song Download - Selenium Implementation
#
# References
# * https://selenium-python.readthedocs.io/
# * https://www.youtube.com/watch?v=YrIlythZc60 -In Java
# * Need to Install specific browserDriver ex:chromedriver for chrome (We can Find it here: https://chromedriver.chromium.org/downloads)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib
import bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
# Collect the Songs List
songs_list = ["Uppenantha","Karige loga","baby he loves you"]

# Song SmuleSearchurl Dictionary
smule_base_url = "https://www.smule.com/"
song_smule_searchurl = {}
for song in songs_list:
    song_smule_searchurl[song] = smule_base_url+"search?q="+song.replace(" ","%20")
song_smule_searchurl
# Get the Recording songs if available:
song_smulerecordingsurls = {}
for song, smuleurl in song_smule_searchurl.items():
    u_client = urlopen(smuleurl)
    data = u_client.read()
    html_page = data.decode('UTF-8')
    search_soup = soup(data,'html.parser')
    u_client.close()
    
print(search_soup.findAll("div",{"class":"recording-wrap"}))
# Out:
# []

# %%
u_client = urlopen(smuleurl)
data = u_client.read()
html_page = data.decode('UTF-8')
u_client.close()
search_soup = soup(html_page,'html.parser')
recordings_elems = search_soup.findAll("a",{"class":"search-result"})
if recordings_elems:
    print("Recordings Available")
    for recording in recordings_elems:
        count = 0
        if recording:
            count +=1
            print(f'count: {count}')
            print(recording)
        else:
            print("No Recording Found")
else:
    print("No Recordings")
# Out:
# No Recordings

# %%
# Collect the Songs List
songs_list = ["Uppenantha","Karige loga","baby he loves you"]

# Song Smuleurl Dictionary
smule_base_url = "https://www.smule.com/"
song_smule_searchurl = {}
for song in songs_list:
    song_smule_searchurl[song] = smule_base_url+"search?q="+song

# Get the first 5 Recording songs if available:
song_smulerecordingurls = {}
for song, smuleurl in song_smuleurl.items():
    u_client = uReq('https://www.smule.com/search?q=Uppenantha')
    html_page = u_client.read()
    u_client.close()
    search_soup = soup(html_page,'html.parser')
    search_soup.findAll("a",{"class":"recording search-result"})
    
    
    
    
# Get the Smule URL
smule_song_url = "https://www.smule.com/recording/aarya-uppenantha-premaki/608550878_706845767/ensembles"


# Launch 'sing.salon' website.
sing_salon_url = "https://sing.salon/smule-downloader/"
driver = webdriver.Chrome("D:/Learnings/Self/SpringBoard-Nishanth/Main-Course/99-CapstonProject/01-HummingProject/01-DataCollection/chromedriver_win32/chromedriver.exe")
driver.get(sing_salon_url)


# enter the url in the fetch box
# click on FetchSong Button
fetch_box = driver.find_element_by_id("url")
fetch_box.clear()
fetch_box.send_keys(smule_song_url)
fetch_box.send_keys(Keys.ENTER)

# find the download button
download_button = driver.find_element_by_xpath("//div[@id='elCmsPageWrap']/a")
# click the download button
song_down_link = download_button.get_attribute("href")
# save it to a specific folder with the song name
driver.get(song_down_lin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-541fd2e0d8bf> in <module>
#      10 # Get the first 5 Recording songs if available:
#      11 song_smulerecordingurls = {}
# ---> 12 for song, smuleurl in song_smuleurl.items():
#      13     u_client = uReq('https://www.smule.com/search?q=Uppenantha')
#      14     html_page = u_client.read()
#
# NameError: name 'song_smuleurl' is not defined

# %%
   
# Get the Smule URL
smule_song_url = "https://www.smule.com/recording/aarya-uppenantha-premaki/608550878_706845767/ensembles"


# Launch 'sing.salon' website.
sing_salon_url = "https://sing.salon/smule-downloader/"
driver = webdriver.Chrome("D:/Learnings/Self/SpringBoard-Nishanth/Main-Course/99-CapstonProject/01-HummingProject/01-DataCollection/chromedriver_win32/chromedriver.exe")
driver.get(sing_salon_url)


# enter the url in the fetch box
# click on FetchSong Button
fetch_box = driver.find_element_by_id("url")
fetch_box.clear()
fetch_box.send_keys(smule_song_url)
fetch_box.send_keys(Keys.ENTER)

# find the download button
download_button = driver.find_element_by_xpath("//div[@id='elCmsPageWrap']/a")
# click the download button
song_down_link = download_button.get_attribute("href")
# save it to a specific folder with the song name
a=driver.get(song_down_link)

# %%
type(a)
# Out:
# NoneType

# %% [markdown]
# import os, time
# path_to_watch = "."
# before = dict ([(f, None) for f in os.listdir (path_to_watch)])
# while 1:
#   time.sleep (10)
#   after = dict ([(f, None) for f in os.listdir (path_to_watch)])
#   added = [f for f in after if not f in before]
#   removed = [f for f in before if not f in after]
#   if added: print "Added: ", ", ".join (added)
#   if removed: print "Removed: ", ", ".join (removed)
#   before = after

# %%
import os, time
import shutil

# %%
path_to_watch = "C:/Users/nvpapara/Downloads"
project_folder = "D:/Learnings/Self/SpringBoard-Nishanth/Main-Course/99-CapstonProject/01-HummingProject/01-DataCollection/Songs_AutoDownload"
before = dict([(f,None) for f in os.listdir(path_to_watch)])

# %%
after = dict([(f,None) for f in os.listdir(path_to_watch)])
added = [f for f in after if not f in before]
removed = [f for f in before if not f in after]
if added: 
    print("Added:",",".join(added))
    if not os.path.exists(project_folder + "/" + song):
        os.makedirs(project_folder + "/" + song)
    shutil.move(path_to_watch + "/" + added[0], project_folder + "/" + song + "/"+ added[0])
if removed: print("Removed:",",".join(removed))
# Out:
# Added: a749bf8d-6e78-4f61-b0cf-62b0b71824da (7).m4a

# %%
song
# Out:
# 'baby he loves you'

# %%
youtube_base_url = "https://www.youtube.com/" 
(youtube_base_url + "results?search_query=" + song.replace(" ","+") + "+full+song")
# Out:
# 'https://www.youtube.com/results?search_query=baby+he+loves+you+full+song'

# %% [markdown]
# ## Downloading the Original song from Youtube

# %%
youtube_base_url = "https://www.youtube.com/" 
u_client = urlopen(youtube_base_url + "results?search_query=" + song.replace(" ","+") + "+full+song")
html_page = u_client.read()
page_soup = soup(html_page,'html.parser')
orig_song_link = page_soup.find("a",{"class":"spf-link"})['href']
if orig_song_link:
    print("Present")
    print(orig_song_link)
else:
    print("Not present")
# Out:
# Present
# /

# %%
youtube_base_url = "https://www.youtube.com/" 
u_client = urlopen(youtube_base_url + "/results?search_query=" + song.replace(" ","+") + "+full+song")
print((youtube_base_url + "/results?search_query=" + song.replace(" ","+") + "+full+song"))
# Out:
# https://www.youtube.com//results?search_query=baby+he+loves+you+full+song

# %%
# Out:
# '<!DOCTYPE html>\n<html data-cast-api-enabled="true" lang="en-IN">\n <head>\n  <style name="www-roboto">\n   @font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}\n  </style>\n  <script name="www-ro
# ...

# %%
u_client.url
# Out:
# 'https://www.youtube.com/results?search_query=baby+he+loves+you+full+song'

# %%
start = str(html_page).find("watch?")
end = str(html_page)[start:].find('"')
youtube_href = str(html_page)[start: start+end]
youtube_href
# Out:
# 'watch?v=lwz5bMN8jX8'

# %%
yout_href = (youtube_base_url + youtube_href)
yout_href
# Out:
# 'https://www.youtube.com/watch?v=lwz5bMN8jX8'

# %%
complete_youtube_url = (youtube_base_url + youtube_href)
ytMP3 = "https://ytmp3.cc/en13/"
driver = webdriver.Chrome("D:/Learnings/Self/SpringBoard-Nishanth/Main-Course/99-CapstonProject/01-HummingProject/01-DataCollection/chromedriver_win32/chromedriver.exe")
driver.get(ytMP3)
driver
download_button = driver.find_element_by_xpath("//div[@class='recorder-action']/button")
download_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-55-d3b6afabfd1f> in <module>
#       3 driver = webdriver.Chrome("D:/Learnings/Self/SpringBoard-Nishanth/Main-Course/99-CapstonProject/01-HummingProject/01-DataCollection/chromedriver_win32/chromedriver.exe")
#       4 driver.get(ytMP3)
# ----> 5 download_button = driver.find_element_by_xpath("//div[@class='recorder-action']/button")
#       6 download_button.click()
#
# D:\Learnings\Self\SpringBoard-Nishanth\Main-Course\01-DataPreparation\env\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
smuleurl
# Out:
# 'https://www.smule.com/search?q=baby%20he%20loves%20you'

# %%
response = requests.get(smuleurl)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    <script>\n  window.DataStore = {\n    meta: {\n      mobile_title: \'false\'\n    },\n    Pages: {\n      Home: {\n         playlists: false,\n         smuleFamilyList: false\n      },\n      Duet: null,\n      Feed: null,\n      Listen: null,\n      Playlist: {\n         currentPlaylist: false\n      },\n      CreationPlayer: null,\n      Profile: null,\n      Settings: null,\n      Upload: null,\n      Upload: false,\n      PasswordReset: null,\n      SongBook: null,\n      Search: null,\n      ProfileEditor: null,\n      Song: null,\n      Composition: null,\n      Billing: {},\n      Recording: null,\n      CurationTool: null,\n      Globe: null,\n      SmuleFamily: null,\n      PartnerArtists: {\n        trending: {\n          artists: false,\n          cursor: false\n        }\n      }\n    },\n    Widgets: {\n      NationContent: null,\n      GlobalSearch: \'/search/autocomplete\',\n      Login: {\n        auth: null,\n        init: {"log
# ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /songs
# /s/smule_groups/list
# /s/billing/pricing/v121
# /sing/about
# /acknowledgments
# /apps
# /jobs
# /press
# /cinebeat/support?controller=community
# http://blog.smule.com
# https://www.smule.com/s/communityguidelines
# https://www.smule.com/termsofservice
# https://www.smule.com/cookiepolicy
# https://www.smule.com/copyright
# https://www.smule.com/privacy
# http://www.facebook.com/Smule
# http://twitter.com/smule
# http://www.youtube.com/user/smuleage
# https://instagram.com/smule
# #
# #
# #
# #
# #
# #
# #
# https://itunes.apple.com/us/app/sing!-karaoke-by-smule/id509993510?mt=8&at=10l3Lc&app=itunes&ct=web_LyricsPages_DL-SingiOS&ls=1
# https://app.adjust.com/dhl068?campaign=Web_Sing_Android_ZZ_LyricsPages_DL-SingAndroid&rt=0&gps_adid=%%ADVERTISING_IDENTIFIER_PLAIN%%
# https://app.adjust.com/ws8zfj?IDFA={IDFA}&campaign=Web_Sing_iOS_ZZ_SongPages_SingButton
# https://app.adjust.com/dhl068?DeviceID={gps_adid}&campaign=Web_Sing_Android_ZZ_SongPages_SingButton
# ...
